# %%
# Pandas data Analysis
# download the file fb.csv

# %%
#1. Count how many number of posts are paid and unpaid

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('datasets/fb.csv')

# %%
d
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
paid=df[df['Paid']!=0]

# %%
number=df['Post Month']+df['Post Weekday']+df['Post Hour']

# %%
sum=number.sum()
sum
# Out:
# 9514

# %%
#2. Display only Page type, Month, likes, comments and shares.

# %%
df[['Type','comment']]
# Out:
#        Type  comment
# 0     Photo        4
# 1    Status        5
# 2     Photo        0
# 3     Photo       58
# 4     Photo       19
# ..      ...      ...
# 495   Photo        5
# 496   Photo        0
# 497   Photo        4
# 498   Photo        7
# 499   Photo        0
#
# [500 rows x 2 columns]

# %%
#3. find average number of like to the post in September month

# %%
a=df[df['Post Month']==9]
a
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 155            135700   Photo         2           9             3          7
# 156            135700   Photo         2           9             2         11
# 157            135700   Photo         3           9             2          2
# 158            135700   Photo         2           9             1         10
# 159            135617   Photo         2           9             1          3
# 160            135617   Photo         3           9             7          9
# 161            135617   Photo         2           9             7          3
# 162            135617   Photo         3           9             6         10
# 163            135617  Status         2           9             6          4
# 164            135428   Photo         1           9             5         10
# 165            135428   Photo         2           9             5          3
# ...

# %%
avg=a['Post Month'].mean()
avg
# Out:
# 9.0

# %%
# print the information about the posts which are likes

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df[df['Lifetime Post Impressions by people who have liked your Page']!=0]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
# How many total shares are presnt for the video posts

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
b=df[df['Type']=='Video']
b
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# ...

# %%
share=b['share'].sum()
share
# Out:
# 365.0

# %%
#6.  In which hour of the day maximum posts are posted

# %%
m=df['Lifetime Post Total Reach'].max()
m
# Out:
# 180480

# %%
c=df[df['Lifetime Post Total Reach']==m]
c
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 244                    8072                     4010
#
#      Lifetime Post Consumptions  \
# 244                        6242
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 244                                             108752
#
#      Lifetime Post reach by people who like your Page  \
# 244                                             51456
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 244                                               3316
#
#      comment    like  share  Total Interactions
# 244      372  5172.0  790.0                6334

# %%
c[['Post Hour']]
# Out:
#      Post Hour
# 244          5

# %%
#7 In which day of october, maximum number of interactions are found?

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
d=df[df['Post Month']==10]
d
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 95             137059   Photo         3          10             6         10
# 96             137059   Photo         1          10             6          3
# 97             137059   Photo         2          10             5         11
# 98             137020  Status         2          10             5          3
# 99             137020   Photo         1          10             4         10
# 100            137020   Photo         1          10             4          9
# 101            137020   Photo         2          10             4          3
# 102            137020   Photo         3          10             3         10
# 103            137020   Photo         1          10             3          4
# 104            137020   Photo         1          10             2         11
# 105            137020   Photo         1          10             2          4
# ...

# %%
z=d['Lifetime Post Total Reach'].max()
z
# Out:
# 70144

# %%
e=d[d['Lifetime Post Total Reach']==z]
e
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 105            137020  Photo         1          10             2          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 105   0.0                      70144                           111745
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 105                    3216                     2628
#
#      Lifetime Post Consumptions  \
# 105                        4782
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 105                                              43671
#
#      Lifetime Post reach by people who like your Page  \
# 105                                             20608
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 105                                               1542
#
#      comment   like  share  Total Interactions
# 105       42  955.0  139.0                1136

# %%
e[['Post Weekday','Lifetime Post Total Reach']]
# Out:
#      Post Weekday  Lifetime Post Total Reach
# 105             2                      70144

# %%
#8. Print the information of the posts werhe likes are above 200 and shares are above 30

# %%
lik=df[(df['like']>200)& (df['share']>30)]
lik
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 26             138458  Status         2          12             5         11
# 28             138895   Photo         2          12             5          3
# 38             138895  Status         2          12             7          9
# ..                ...     ...       ...         ...           ...        ...
# 464             92079   Photo         1           2             6         13
# 468             91651   Photo         1           2             4         12
# 476             86909   Photo         1           1             6         10
# 480             86909   Photo         2           1             4         11
# 488             85979   Photo         3           1             7         10
#
# ...

# %%
#9. Which kind of posts are posted maximum number of tims in NOvember month

# %%
posmax=df[df['Post Month']==10]
posmax
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 95             137059   Photo         3          10             6         10
# 96             137059   Photo         1          10             6          3
# 97             137059   Photo         2          10             5         11
# 98             137020  Status         2          10             5          3
# 99             137020   Photo         1          10             4         10
# 100            137020   Photo         1          10             4          9
# 101            137020   Photo         2          10             4          3
# 102            137020   Photo         3          10             3         10
# 103            137020   Photo         1          10             3          4
# 104            137020   Photo         1          10             2         11
# 105            137020   Photo         1          10             2          4
# ...

# %%
maxi=posmax['Lifetime Post Total Reach'].max()
maxi
# Out:
# 70144

# %%
kind=posmax[posmax['Lifetime Post Total Reach']==maxi]
kind
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 105            137020  Photo         1          10             2          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 105   0.0                      70144                           111745
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 105                    3216                     2628
#
#      Lifetime Post Consumptions  \
# 105                        4782
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 105                                              43671
#
#      Lifetime Post reach by people who like your Page  \
# 105                                             20608
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 105                                               1542
#
#      comment   like  share  Total Interactions
# 105       42  955.0  139.0                1136

# %%
kind[['Type','Lifetime Post Total Reach']]
# Out:
#       Type  Lifetime Post Total Reach
# 105  Photo                      70144

# %%
#10. find average and median of interactions for the paid(1) posts

# %%
pd=df[df['Paid']==1]
pd
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 6              139441  Photo         3          12             1          3
# 7              139441  Photo         3          12             7          9
# 14             138414  Photo         2          12             4          5
# 17             138414  Photo         1          12             2         12
# ..                ...    ...       ...         ...           ...        ...
# 473             91116  Photo         3           2             2          4
# 475             86909  Photo         3           1             6         16
# 476             86909  Photo         1           1             6         10
# 481             86491   Link         1           1             4          4
# 491             85979  Photo         3           1             6          3
#
# ...

# %%
avg=pd['Total Interactions'].mean()
avg
# Out:
# 278.23021582733816

# %%
mead=pd['Total Interactions'].median()
mead
# Out:
# 158.0
