# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
cent=int(input('enter the teperatur:'))
far=cent*1.8+32
print('farenhite Temp',far)
# Out:
# enter the teperatur: -40
# farenhite Temp -40.0

# %%
#####simple python program

# %%
a=int(input('enter a number'))
if a>0:
    print('Number is positive')
elif a==0:
    print('Number is zero')
else:
    print(type(a))
# Out:
# enter a number -10
# <class 'int'>

# %%
count=0
while (count<10):
    print('tushar')
    count=count+1
# Out:
# tushar
# tushar
# tushar
# tushar
# tushar
# tushar
# tushar
# tushar
# tushar
# tushar

# %%
for i in 67,23,16,33,27:
    print(i)
# Out:
# 67
# 23
# 16
# 33
# 27

# %%
for i in 'Pune':
    print(i*10)
# Out:
# PPPPPPPPPP
# uuuuuuuuuu
# nnnnnnnnnn
# eeeeeeeeee

# %%
for x in range(100):
    print(x*x)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801

# %%
for x in range(10):
    if x==5:
        continue
    print(x*x)
# Out:
# 0
# 1
# 4
# 9
# 16
# 36
# 49
# 64
# 81

# %%
def square(num):
    sq=num*num
    return sq

# %%
square(4)
# Out:
# 16

# %%
def calc(num):
    sq=num*num
    cu=num**3
    return sq,cu

# %%
calc(3)
# Out:
# (9, 27)

# %%
###### Data Structur

# %%
num1=[1,2,3,4,5]

# %%
type[num1]
# Out:
# type[[1, 2, 3, 4, 5]]

# %%
type(num1)
# Out:
# list

# %%
num1{5}
# Out:
#   Cell In[43], line 1
#     num1{5}
#         ^
# SyntaxError: invalid syntax

# %%
num1[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 num1[5]
#
# IndexError: list index out of range

# %%
num1[2]
# Out:
# 3

# %%
num2=(1,2,3)

# %%
type(num2)
# Out:
# tuple

# %%
num1[2]=100

# %%
num2[2]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 num2[2]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
num3={1,2,3}

# %%
num3[2]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 num3[2]=2
#
# TypeError: 'set' object does not support item assignment

# %%
num4={1:100,2:200}

# %%
type(num4)
# Out:
# dict

# %%
num4[1]
# Out:
# 100

# %%
num4={'x':300}

# %%
num4['x']
# Out:
# 300

# %%
#####class

# %%
num1.reverse()

# %%
class Person:
    def __init__(self,n,a):
        self.name=n
        self.age=a
    def show(self):
        print('values are:')
        print(self.name,self.age)

# %%
p1=Person('ajay',34)

# %%
p1.name
# Out:
# 'ajay'

# %%
p1.age
# Out:
# 34

# %%
p1.show()
# Out:
# values are:
# ajay 34

# %%
class Person:
    def __init__(self,n,a):
        self.name=n
        self.age=a
    def show(self):
        print('values are:')
        print(self.name,self.age)

# %%
import math

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
math.sqrt(23)
# Out:
# 4.795831523312719

# %%
math.fatorial(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 math.fatorial(5)
#
# AttributeError: module 'math' has no attribute 'fatorial'

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import math as m

# %%
m.sqrt()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 m.sqrt()
#
# TypeError: math.sqrt() takes exactly one argument (0 given)

# %%
m.sqrt(30)
# Out:
# 5.477225575051661

# %%
from math import sqrt,pi

# %%
sqrt(24)
# Out:
# 4.898979485566356

# %%
import numpy as np

# %%
####create the array

# %%
x=np.array([56,12,35,71,11,28])

# %%
print(x)
# Out:
# [56 12 35 71 11 28]

# %%
x.ndim
# Out:
# 1

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([56, 12, 35, 71, 11, 28])

# %%
x.dtype
# Out:
# dtype('int32')

# %%
x=np.array([20,30,42],dtype=np.int8)

# %%
x
# Out:
# array([20, 30, 42], dtype=int8)

# %%
x.dtype
# Out:
# dtype('int8')

# %%
np.array([1,12], dtype=uint8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 np.array([1,12], dtype=uint8)
#
# NameError: name 'uint8' is not defined

# %%
np.arrange(2,20,.33)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 np.arrange(2,20,.33)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
np.arange(2,10,.33)
# Out:
# array([2.  , 2.33, 2.66, 2.99, 3.32, 3.65, 3.98, 4.31, 4.64, 4.97, 5.3 ,
#        5.63, 5.96, 6.29, 6.62, 6.95, 7.28, 7.61, 7.94, 8.27, 8.6 , 8.93,
#        9.26, 9.59, 9.92])

# %% [markdown]
# ##### arrary operation

# %%
num1=np.array([56,12,33,14,68,99])
num2=np.array([28,28,19,39,38,74])

# %%
num1+10
# Out:
# array([ 66,  22,  43,  24,  78, 109])

# %%
num1/5
# Out:
# array([11.2,  2.4,  6.6,  2.8, 13.6, 19.8])

# %%
num1*4
# Out:
# array([224,  48, 132,  56, 272, 396])

# %%
[28,28,19,39,38,74]*3
# Out:
# [28, 28, 19, 39, 38, 74, 28, 28, 19, 39, 38, 74, 28, 28, 19, 39, 38, 74]

# %%
num1+num2
# Out:
# array([ 84,  40,  52,  53, 106, 173])

# %%
num1-num2
# Out:
# array([ 28, -16,  14, -25,  30,  25])

# %%
num1=np.array([[56,12,33,14,68,99],[28,28,19,39,38,74]], dtype=int8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 num1=np.array([[56,12,33,14,68,99],[28,28,19,39,38,74]], dtype=int8)
#
# NameError: name 'np' is not defined

# %%
num1
# Out:
# array([[56, 12, 33, 14, 68, 99],
#        [28, 28, 19, 39, 38, 74]])

# %%
num1.dtype
# Out:
# dtype('int32')

# %%
num1.shape
# Out:
# (2, 6)

# %%
num1.size
# Out:
# 12

# %%
num1.ndim
# Out:
# 2

# %%
num1[0][1]
# Out:
# 12

# %%
num1[0,1]
# Out:
# 12

# %%
num1.t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 num1.t
#
# AttributeError: 'numpy.ndarray' object has no attribute 't'

# %%
num1.T
# Out:
# array([[56, 28],
#        [12, 28],
#        [33, 19],
#        [14, 39],
#        [68, 38],
#        [99, 74]])

# %%
num1.reshape(4,3)
# Out:
# array([[56, 12, 33],
#        [14, 68, 99],
#        [28, 28, 19],
#        [39, 38, 74]])

# %%
y=np.array([10][20], dtype=uint8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y=np.array([10][20], dtype=uint8)
#
# NameError: name 'np' is not defined

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow -U

# %%
pip intall tensorflow -U
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "intall" - maybe you meant "install"

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached tensorflow-2.16.2-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# ...
#   Using cached tensorflow_intel-2.16.2-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# ...
#   Using cached gast-0.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached h5py-3.11.0-cp311-cp311-win_amd64.whl.metadata (2.5 kB)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached ml_dtypes-0.3.2-cp311-cp311-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...

# %%
pip install tensorflow -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

# %%
tf
# Out:
# <module 'tensorflow' from 'C:\\Users\\rajesh\\AppData\\Roaming\\Python\\Python311\\site-packages\\tensorflow\\__init__.py'>

# %%
import numpy as np

# %%
#create tensor
a=tf.constant([1,2,3])
b=tf.constant([4,5,6])
print("tensor a:",a)
print("tensor b:",b)
# Out:
# tensor a: tf.Tensor([1 2 3], shape=(3,), dtype=int32)
# tensor b: tf.Tensor([4 5 6], shape=(3,), dtype=int32)

# %%
c=tf.add(a,b)
print(c)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 c=tf.add(a,b)
#       2 print(c)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
# ...

# %%
a=tf.constant([[1,2,3],[7,8,9]],dtype=np.int8)
b=tf.constant([[4,5],[10,11]])
print("tensor a:",a)
print("tensor b:",b)
# Out:
# tensor a: tf.Tensor(
# [[1 2 3]
#  [7 8 9]], shape=(2, 3), dtype=int8)
# tensor b: tf.Tensor(
# [[ 4  5]
#  [10 11]], shape=(2, 2), dtype=int32)

# %%
a=tf.constant([[[1,2,3],[7,8,9]],[[0,2,5],[7,6,8]]],dtype=np.int8)
b=tf.constant([[4,5],[10,11]])
print("tensor a:",a)
print("tensor b:",b)
# Out:
# tensor a: tf.Tensor(
# [[[1 2 3]
#   [7 8 9]]
#
#  [[0 2 5]
#   [7 6 8]]], shape=(2, 2, 3), dtype=int8)
# tensor b: tf.Tensor(
# [[ 4  5]
#  [10 11]], shape=(2, 2), dtype=int32)

# %%
c=tf.subtract(b,a)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 c=tf.subtract(b,a)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\framework\ops.py:5983, in raise_from_not_ok_status(e, name)
#    5981 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5982   e.message += (" name: " + str(name if name is not None else ""))
# -> 5983   raise core._status_to_exception(e) from None
#
# ...

# %%
a=tf.constant([1,2,3], dtype=np.int8)
b=tf.constant([4,5,6], dtype=np.int8)

# %%
c=tf.add(a,b)

# %%
d=tf.subtract(a,b)

# %%
d.numpy()
# Out:
# array([-3, -3, -3])

# %%
a*b
# Out:
# <tf.Tensor: shape=(3,), dtype=int8, numpy=array([ 4, 10, 18], dtype=int8)>

# %%
a/b
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([0.25, 0.4 , 0.5 ], dtype=float32)>

# %%
a//b
# Out:
# <tf.Tensor: shape=(3,), dtype=int8, numpy=array([0, 0, 0], dtype=int8)>

# %%
#using // for getting full integer

# %%
b//a
# Out:
# <tf.Tensor: shape=(3,), dtype=int8, numpy=array([4, 2, 2], dtype=int8)>

# %%
b/a
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([4. , 2.5, 2. ], dtype=float32)>

# %%
#matrix multiplication
a=tf.constant([[1,2],[3,4]])
b=tf.constant([[5,6],[7,8]])
g=tf.matmul(a,b)
print(g)
# Out:
# tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)

# %%
#matrix multiplication
a=tf.constant([[1,2],[3,4]])
b=tf.constant([[5,6,8],[7,8,9]])
g=tf.matmul(a,b)
print(g)
# Out:
# tf.Tensor(
# [[19 22 26]
#  [43 50 60]], shape=(2, 3), dtype=int32)

# %%
pip install opencv-python pillow scikit-image -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.8 MB 1.7 MB/s eta 0:00:24
#    ---------------------------------------- 0.2/38.8 MB 3.7 MB/s eta 0:00:11
#     --------------------------------------- 0.6/38.8 MB 5.8 MB/s eta 0:00:07
#     --------------------------------------- 0.6/38.8 MB 5.7 MB/s eta 0:00:07
#     --------------------------------------- 0.9/38.8 MB 6.3 MB/s eta 0:00:07
#    - -------------------------------------- 1.4/38.8 MB 6.8 MB/s eta 0:00:06
#    - -------------------------------------- 1.9/38.8 MB 7.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.3/38.8 MB 8.2 MB/s eta 0:00:05
#    -- ------------------------------------- 2.8/38.8 MB 8.9 MB/s eta 0:00:05
#    --- ------------------------------------ 3.3/38.8 MB 9.5 MB/s eta 0:00:04
# ...

# %%
import cv2

# %%
#https://mitu.co.in/dataset (google drive folder)
#download all the files from/ images folder and store in your current working directory

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %%
 img1=cv2.imread('images/lenna.png')

# %%
cv2.imshow('first Image',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
img_plt=plt.imread('images/lenna.png')
plt.imshow(img_plt)

# %%
from skimage import io

# %%
img_ski=io.imread('images/lenna.png')

# %%
plt.imshow(img_ski)

# %% [markdown]
# using pillow

# %%
from PIL import Image

# %%
img_pil=Image.open('images/lenna.png')

# %%
img_pil.show()

# %%
img_pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %% [markdown]
# tensorflow method

# %%
import tensorflow as tf
img_tf=tf.io.read_file('images/lenna.png')
img_tf=tf.image.decode_image(img_tf,channels=3)

# %%
plt.imshow(img_tf)

# %%
img_tf.shape
# Out:
# TensorShape([512, 512, 3])

# %%
img_ski.shape
# Out:
# (512, 512, 3)

# %%
img_pil.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 img_pil.shape
#
# AttributeError: 'PngImageFile' object has no attribute 'shape'

# %%
# pil is not an array it is just a picture but others are array

# %%
type(img1), type(img_plt)
# Out:
# (NoneType, numpy.ndarray)

# %%
img1.dtype, img_plt.dtype
# Out:
# (dtype('uint8'), dtype('float32'))

# %%
img_ski.dtype
# Out:
# dtype('uint8')

# %%
img_tf.dtype
# Out:
# tf.uint8

# %%
img_plt
# Out:
# array([[[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        ...,
#
#        [[0.32941177, 0.07058824, 0.23529412],
# ...

# %%
import numpy as np

# %%
img_new=np.zeros([100,100])

# %%
plt.imshow(img_new)

# %%
plt.imshow(img_new, cmap ='gray')

# %%
img_new[34,57]=0.5

# %%
plt.imshow(img_new, cmap ='gray')

# %%
img_new[34]=1

# %%
plt.imshow(img_new, cmap ='gray')

# %%
np.random.randint(12,78)
# Out:
# 70

# %%
img_new=np.zeros([100,100],dtype=np.uint8)

# %%
for i in range(100):
    for j in range(100):
        img_new[i,j]=np.random.randint(0,255)

# %%
plt.imshow(img_new,cmap='gray')

# %% [markdown]
# ##### Grayscale

# %%
img_gray=cv2.imread('images/lenna.png',0)

# %%
img_gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img_tf.shape
# Out:
# TensorShape([512, 512, 3])

# %%
img_gray.shape
# Out:
# (512, 512)

# %%
r=img_plt[:,:,0]
g=img_plt[:,:,1]
b=img_plt[:,:,2]

# %%
r.shape, g.shape, b.shape
# Out:
# ((512, 512), (512, 512), (512, 512))

# %%
plt.subplot(1,3,1)
plt.imshow(r,cmap='gray')
plt.subplot(1,3,2)
plt.imshow(g,cmap='gray')
plt.subplot(1,3,3)
plt.imshow(b,cmap='gray')

# %%
plt.subplot(1,3,1)
plt.imshow(r,cmap='Reds')
plt.subplot(1,3,2)
plt.imshow(g,cmap='Greens')
plt.subplot(1,3,3)
plt.imshow(b,cmap='Blues')

# %%
new_img=(r+g+b)/3

# %%
plt.imshow(new_img,cmap='gray')

# %%
plt.subplot(1,2,1)
plt.title('image read using cv2')
plt.imshow(img1)
plt.subplot(1,2,2)
plt.title('Image Red using matplotlib')
plt.imshow(img_plt)

# %%
img2=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
plt.subplot(1,2,1)
plt.title('image read using cv2')
plt.imshow(img2)
plt.subplot(1,2,2)
plt.title('Image Red using matplotlib')
plt.imshow(img_plt)

# %%
import sys

# %%
sys.getsizeof(img1)
# Out:
# 786576

# %%
sys.getsizeof(img_plt)
# Out:
# 3145872

# %%
sys.getsizeof(img2)
# Out:
# 786576
