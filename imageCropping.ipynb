# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img=plt.imread('images/lenna.png')

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
#crop the image , starting and ending point of x and y

# %%
new_img=img[150:300,200:350]

# %%
plt.imshow(new_img)

# %%
# from all the angle delete 15% part of the image

# %%
 img_array = np.array(new_img)
height, width = img_array.shape
crop_height = int(height * percentage / 100)
crop_width = int(width * percentage / 100)
cropped_img = img_array[crop_height:height-crop_height, crop_width:width-crop_width, :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 new_img=img[.85:.85,.85:.85]
#       2 plt.imshow(new_img)
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
height, width, channels=img.shape

# %%
startRow=int(height*.15)
startCol=int(width*.15)
endRow=int(height*.85)
endCol=int(width*.85)

# %%
croppedImage=img[startRow:endRow, startCol:endCol]

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(croppedImage)

# %%
x=np.array([[5,6,7],[1,2,3],[8,0,9]])
y=np.array([[2,5,8],[1,9,0],[3,2,5]])

# %%
x
# Out:
# array([[5, 6, 7],
#        [1, 2, 3],
#        [8, 0, 9]])

# %%
y
# Out:
# array([[2, 5, 8],
#        [1, 9, 0],
#        [3, 2, 5]])

# %%
z=np.hstack([x,y]) # horizontal stack , row should be equale
z
# Out:
# array([[5, 6, 7, 2, 5, 8],
#        [1, 2, 3, 1, 9, 0],
#        [8, 0, 9, 3, 2, 5]])

# %%
m=np.vstack([x,y]) # vertical stack, column should be equale
m
# Out:
# array([[5, 6, 7],
#        [1, 2, 3],
#        [8, 0, 9],
#        [2, 5, 8],
#        [1, 9, 0],
#        [3, 2, 5]])

# %%
#flip the image horizontally
flipped_horizontal=cv2.flip(img,0)

# %%
new_img=np.hstack([img,flipped_horizontal])

# %%
plt.imshow(new_img)
